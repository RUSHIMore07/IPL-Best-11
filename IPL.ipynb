# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\rushi\\Downloads\\IPLData.csv')
df
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# ...

# %%
df.isna().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
cbatters=df.query("Player_Type=='Batter' & Capped==1")
cbatters
batsman=cbatters.iloc[:,0:9]
batsman = batsman.drop(columns=['Player_Type','Capped'])
batsman.head()
# Out:
#        Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0   Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1    Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2   Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3   Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4  Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
#
#    Strike_Rate
# 0       126.60
# 1       123.96
# 2       131.09
# 3       121.83
# 4       151.17

# %%
ab=df.loc[(df['Player_Type']=='Bowler ') & (df['Capped']==1)]
ab

bowler=ab.loc[:,['Player Name','Team','Nationality','Matches_Played','Wickets','Bowling_average','Economy','Bowling_Strike_Rate']]
bowler.head()
# Out:
#         Player Name       Team Nationality  Matches_Played  Wickets  \
# 36   Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 37     Trent Boult   Rajasthan    Overseas            62.0     76.0
# 38  Mohammad Shami     Gujarat      Indian            77.0     79.0
# 39      T Natarajan  Hyderabad      Indian            24.0     20.0
# 40   Deepak Chahar     Chennai      Indian            63.0     59.0
#
#     Bowling_average  Economy  Bowling_Strike_Rate
# 36            20.53     8.21                15.00
# 37            26.09     8.40                18.64
# 38            30.41     8.63                21.14
# 39            34.40     8.24                25.05
# 40            29.19     7.80                22.44

# %%
ca=df.query("Player_Type=='Allrounder' & Capped==1")
ars=ca.iloc[:,0:13]
ar=ars.drop(columns=["Player_Type",'Capped'])
ar.head()
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
#
#      Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 127    11.12       109.88    145.0            27.80     6.91
# 128    19.75       140.44     38.0            30.13     8.24
# 129    22.94       130.25    167.0            24.32     8.36
# 130    28.00       132.46      7.0            22.00     8.03
# 131    14.54       121.15     35.0            22.46     8.20
#
#      Bowling_Strike_Rate
# 127                24.12
# 128                21.95
# 129                17.44
# 130                16.43
# 131                16.43

# %%
cw=df.query("Player_Type=='Keeper' & Capped==1")
cwk=cw.loc[:,['Player Name','Team','Nationality','Matches_Played','Runs','Average','Strike_Rate','Catches','Run_outs','Stumps']]
cwk.tail()
# Out:
#        Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 121   Vishnu Vinod  Hyderabad      Indian             3.0    19.0     6.30
# 206  Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209   Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 213       MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 219     Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 121        73.10      0.0       0.0     2.0
# 206       147.46     56.0       5.0    14.0
# 209       134.21     59.0       8.0    10.0
# 213       135.80    126.0      21.0    39.0
# 219       150.00     34.0       3.0     1.0

# %%
allrounder=ar.fillna(0)
Batter=batsman.fillna(0)
keeper=cwk.fillna(0)
Bowler=bowler.fillna(0)

# %%
print(allrounder.isna().sum())
print(Batter.isna().sum())
print(keeper.isna().sum())
print(Bowler.isna().sum())
# Out:
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64

# %%
topbatter_avg
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
topbatter_str
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
topbatter_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %%
topbatter_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %% [markdown]
# ### 1.David w 2.KLR 3.Vk

# %%
topbowler=Bowler.loc[(Bowler['Bowling_average']<=25)]
topbowler
topbowler_avg=topbowler.sort_values('Bowling_average')
topbowler_eco=topbowler.sort_values("Economy")
topbowler_str=topbowler.sort_values('Bowling_Strike_Rate')
topbowler_matches=topbowler.sort_values('Matches_Played',ascending=False)

# %%
topbowler_avg
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# ...

# %%
topbowler_eco
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 65        Khaleel Ahmed       Delhi      Indian            24.0     32.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# ...

# %%
topbowler=Bowler.loc[(Bowler['Bowling_average']<=25)]
topbowler
topbowler_avg=topbowler.sort_values('Bowling_average')
topbowler_eco=topbowler.sort_values("Economy")
topbowler_str=topbowler.sort_values('Bowling_Strike_Rate')
topbowler_matches=topbowler.sort_values('Matches_Played',ascending=False)

# %%
df['Player_Type'].unique()
# Out:
# array(['Batter', 'Bowler ', 'Keeper', 'Allrounder'], dtype=object)

# %%
topbowler_str
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 65        Khaleel Ahmed       Delhi      Indian            24.0     32.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# ...

# %%
topbowler_matches
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 65        Khaleel Ahmed       Delhi      Indian            24.0     32.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# ...

# %% [markdown]
# ####
# 1.Kagiso Rabada
# 2. Jasprit Bumarah
# 3. Yuzvendra Chahal
# 4.Varun Chakravarthy

# %%
allrounder.head()
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
#
#      Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 127    11.12       109.88    145.0            27.80     6.91
# 128    19.75       140.44     38.0            30.13     8.24
# 129    22.94       130.25    167.0            24.32     8.36
# 130    28.00       132.46      7.0            22.00     8.03
# 131    14.54       121.15     35.0            22.46     8.20
#
#      Bowling_Strike_Rate
# 127                24.12
# 128                21.95
# 129                17.44
# 130                16.43
# 131                16.43

# %%
top_allrounder = allrounder.loc[allrounder['Strike_Rate']>140]
top_al_avg = top_allrounder.sort_values('Average', ascending=False)
top_al_str = top_allrounder.sort_values('Strike_Rate', ascending=False)
top_al_matches = top_allrounder.sort_values('Matches_Played', ascending=False)
top_al_Wickets = top_allrounder.sort_values('Matches_Played', ascending=False)
top_al_Bowling_average = top_allrounder.sort_values('Bowling_average')

# %%
top_al_avg
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_al_str
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
#
# ...

# %%
top_al_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_al_Wickets
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_al_Bowling_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %% [markdown]
# ####
# 1.Andre Russell
# 2.Sunil Narine
# 3.Hardik Pandya
# 4.Jofra Archer

# %%
top_keeper=keeper.loc[(keeper['Strike_Rate']>130) & (keeper["Average"]>=35)]
top_keeper
# Out:
#         Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 108  Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 206   Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 213        MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 219      Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 108       142.20     18.0       1.0     4.0
# 206       147.46     56.0       5.0    14.0
# 213       135.80    126.0      21.0    39.0
# 219       150.00     34.0       3.0     1.0

# %% [markdown]
# ####
# 1.MS Dhoni
# 2.Rishabh Pant

# %%
top_Middle_Batter=Batter.loc[(Batter['Average']>30) & (Batter['Strike_Rate']>120) ]
top_matchplayed=top_Middle_Batter.sort_values('Matches_Played', ascending=False)
top_avg=top_Middle_Batter.sort_values('Average', ascending=False)

# %%
top_matchplayed
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 205     Rohit Sharma      Mumbai      Indian           213.0  5611.0    31.17
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 3      Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 14    Ajinkya Rahane     Kolkata      Indian           151.0  3941.0    31.53
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 207   Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# ...

# %%
top_avg
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231   Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207   Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 7    Devdutt Padikkal  Rajasthan      Indian            29.0   884.0    31.57
# 14    Ajinkya Rahane     Kolkata      Indian           151.0  3941.0    31.53
# ...

# %% [markdown]
# ###
# 1.David Warner (Overseas)
# 2.KL Rahul
# 3.Virat Kohli
# 4.Rishabh Pant
# 5.Ms Dhoni
# 6.Hardik Pandya
# 7.Andre russel (Overseas)
# 8.Sunile Narine(Overseas)
# 9.Jofra archer (Overseas)
# 10.Jasprit Boomrah
# 11.Yuzuvendra Chahal
